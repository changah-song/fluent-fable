# %%
from konlpy.tag import Hannanum
from konlpy.tag import Okt
from konlpy.tag import Kkma
from konlpy.tag import Komoran
from mecab import MeCab

komoran = Komoran()
kkma = Kkma()
okt = Okt()
han = Hannanum()
mecab = MeCab()
example = u'6일 인스타그램과 엑스(X·옛 트위터) 등 사회관계망서비스(SNS)에는 전날부터 다양한 투표 인증 사진이 올라왔다. 이 중 젊은 세대의 눈길을 사로잡은 것은 손바닥만 한 크기의 종이를 들고 찍은 인증 사진이다. 이는 유권자가 투표소로 향하기 전 직접 챙겨간 인증 용지다. 손등에 도장을 남기던 방식에서 벗어나 투표 인증을 위한 이미지를 만든 것이다. 인증 용지에 등장하는 이미지는 만화 캐릭터, 이모티콘 캐릭터, 프로야구팀 등 다양하다. 자신의 관심 분야에 맞춰 직접 용지를 만들거나 SNS에 무료 배포된 이미지를 출력해 사용한다. 아이돌 팬들은 최애 멤버의 포토카드를 활용하기도 한다. 인증 방법은 정해져 있다. 그림 속 비워진 공간이나 글자에 기표 도장을 찍어 이미지를 완성시키면 된다.'

# %%
print(okt.pos('공간이나', stem=True))
print(okt.pos('글자에', stem=True))
print(okt.pos('완성시키다', stem=True))
print(okt.pos('이미지를', stem=True))
print(okt.pos('빨리청소', stem=True))
print(okt.pos('인스타그램', stem=True))
print(okt.pos('헌옷', stem=True))
print(okt.pos('사로잡다', stem=True))
# Out:
# [('공간', 'Noun'), ('이나', 'Josa')]
# [('글자', 'Noun'), ('에', 'Josa')]
# [('완성', 'Noun'), ('시키다', 'Verb')]
# [('이미지', 'Noun'), ('를', 'Josa')]
# [('빨리', 'Adverb'), ('청소', 'Noun')]
# [('인스타그램', 'Noun')]
# [('헌', 'Modifier'), ('옷', 'Noun')]
# [('사로자다', 'Verb')]

# %% [markdown]
# ## Han

# %%
print(han.pos(u'질문이나 건의사항은 깃헙 이슈 트래커에 남겨주세요.'))
print(han.morphs(u'우리나라에는 무릎 치료를 잘하는 정형외과가 없는가!'))
print(han.pos(u'우는 사람은 울면 안 됀다고 생각하면서 운다 굳혔다고'))
# Out:
# [('질문', 'N'), ('이나', 'J'), ('건의사항', 'N'), ('은', 'J'), ('깃헙', 'N'), ('이슈', 'N'), ('트래커', 'N'), ('에', 'J'), ('남기', 'P'), ('어', 'E'), ('주', 'P'), ('세', 'E'), ('요', 'J'), ('.', 'S')]
# ['우리나라', '에는', '무릎', '치료', '를', '잘하', '는', '정형외과', '가', '없', '는가', '!']
# [('울', 'P'), ('는', 'E'), ('사람', 'N'), ('은', 'J'), ('울', 'P'), ('면', 'E'), ('알', 'P'), ('ㄴ', 'E'), ('됀다', 'N'), ('이', 'J'), ('고', 'E'), ('생각', 'N'), ('하', 'X'), ('면서', 'E'), ('울', 'P'), ('ㄴ다', 'E'), ('굳히', 'P'), ('었다고', 'E')]

# %%
print(han.pos(u'질문이나 건의 사항은 깃헙 이슈 트래커에 남겨주세요. 굳혔다고'))
print()
print(han.pos(u'질문이나 건의 사항은 깃헙 이슈 트래커에 남겨주세요. 굳혔다고'))
print()
print(han.morphs(u'남기고, 남기는데, 남기니, 남기면, 남긴, 남기는, 남길, 남깁니다'))
# Out:
# [('질문', 'N'), ('이나', 'J'), ('건', 'N'), ('의', 'J'), ('사항', 'N'), ('은', 'J'), ('깃헙', 'N'), ('이슈', 'N'), ('트래커', 'N'), ('에', 'J'), ('남기', 'P'), ('어', 'E'), ('주', 'P'), ('세', 'E'), ('요', 'J'), ('.', 'S'), ('굳히', 'P'), ('었다고', 'E')]
#
# [('질문', 'N'), ('이나', 'J'), ('건', 'N'), ('의', 'J'), ('사항', 'N'), ('은', 'J'), ('깃헙', 'N'), ('이슈', 'N'), ('트래커', 'N'), ('에', 'J'), ('남기', 'P'), ('어', 'E'), ('주', 'P'), ('세', 'E'), ('요', 'J'), ('.', 'S'), ('굳히', 'P'), ('었다고', 'E')]
#
# ['남기', '고', ',', '남기', 'ㄴ데', ',', '남기', '니', ',', '남기', '면', ',', '남기', 'ㄴ', ',', '남', '기', '는', ',', '남기', 'ㄹ', ',', '남기', 'ㅂ니다']

# %% [markdown]
# #### don't know why it messed up at 남기는...

# %%
print(han.morphs(example))
# Out:
# ['6', '이', 'ㄹ', '인스타그램', '과', '엑스(X·옛', '트위터)', '등', '사회관계망서비스(SNS)', '에는', '전날', '부터', '다양한', '투표', '인증', '사진', '이', '오르', '아', '오', '아다', '.', '이', '중', '젊', '은', '세대', '의', '눈길', '을', '사로잡', '은', '것', '은', '손바닥', '만', '하', 'ㄴ', '크', '기', '의', '종이', '를', '들', '고', '찍', '은', '인증', '사진', '이', '다', '.', '이', '는', '유권자', '가', '투표소', '로', '향하', '기', '전', '직접', '챙기', '어', '가', 'ㄴ', '인증', '용지', '이', '다', '.', '손등', '에', '도장', '을', '남기', '던', '방식', '에서', '벗', '어', '나', '아', '투표', '인증', '을', '위하', 'ㄴ', '이미지', '를', '만들', 'ㄴ', '것', '이', '다', '.', '인증', '용지', '에', '등장', '하', '는', '이미지', '는', '만화', '캐릭터', ',', '이모티콘', '캐릭터', ',', '프로야구팀', '등', '다양', '하', '다', '.', '자신', '의', '관심', '분야', '에', '맞추', '어', '직접', '용지', '를', '만들', '거나', 'SNS', '에', '무료', '배포', '되', 'ㄴ', '이미지', '를', '출력', '하', '어', '사용', '하', 'ㄴ다', '.', '아이돌', '패', 'ㄴ', '들', '은', '최애', '멤버', '의', '포토카드', '를', '활용', '하', '기', '도', '하', 'ㄴ다', '.', '인증', '방법', '은', '정하', '어', '지', '어', '있', '다', '.', '그리', 'ㅁ', '속', '비우', '어', '지', 'ㄴ', 
# ...

# %%
print(han.morphs(u'사람의 문의 사항 문과 책'))
# Out:
# ['사람', '의', '문', '의', '사항', '문', '과', '책']

# %% [markdown]
# ## Okt

# %%
print(okt.morphs(u'질문이나 건의 문의 사항은 깃헙 이슈 트래커에 남겨주세요.'))
print(okt.morphs(u'우리나라에는 무릎 치료를 잘하는 정형외과가 없는가!', stem=True))
print(okt.pos(u'우는 사람은 울면 안 됀다고 생각하면서 운다 굳혔다고 문의, 문의 다리', stem=True))
# Out:
# ['질문', '이나', '건의', '문의', '사항', '은', '깃', '헙', '이슈', '트래커', '에', '남겨주세요', '.']
# ['우리나라', '에는', '무릎', '치료', '를', '잘', '하다', '정형외과', '가', '없다', '!']
# [('울다', 'Verb'), ('사람', 'Noun'), ('은', 'Josa'), ('울면', 'Noun'), ('안', 'Noun'), ('돼다', 'Verb'), ('생각', 'Noun'), ('하다', 'Verb'), ('울다', 'Verb'), ('굳히다', 'Verb'), ('문의', 'Noun'), (',', 'Punctuation'), ('문의', 'Noun'), ('다리', 'Noun')]

# %%
print(okt.morphs(u'사람의 문의 사항 문과 책. 문과 책은 물건이다. 사람과의 평화적 공존', stem=True))
# Out:
# ['사람', '의', '문의', '사항', '문과', '책', '.', '문과', '책', '은', '물건', '이다', '.', '사람', '과의', '평화', '적', '공존']

# %%
print(okt.morphs(u'질문이나 건의 사항은 깃헙 이슈 트래커에 남겨주세요. 굳혔다고', stem=True))
print()
print(okt.pos(u'질문이나 건의 사항은 깃헙 이슈 트래커에 남겨주세요. 굳혔다고', stem=True))
print()
print(okt.morphs('남기고, 남기는데, 남기니, 남기면, 남긴, 남기는, 남길, 남깁니다', stem=True))
# Out:
# ['질문', '이나', '건의', '사항', '은', '깃', '허다', '이슈', '트래커', '에', '남기다', '.', '굳히다']
#
# [('질문', 'Noun'), ('이나', 'Josa'), ('건의', 'Noun'), ('사항', 'Noun'), ('은', 'Josa'), ('깃', 'Noun'), ('허다', 'Verb'), ('이슈', 'Noun'), ('트래커', 'Noun'), ('에', 'Josa'), ('남기다', 'Verb'), ('.', 'Punctuation'), ('굳히다', 'Verb')]
#
# ['남다', ',', '남기다', ',', '남기다', ',', '남다', ',', '남기다', ',', '남기다', ',', '남다', ',', '남기다']

# %%
print(okt.morphs(example, stem=True))
# Out:
# ['6일', '인스타그램', '과', '엑스', '(', 'X', '·', '옛', '트위터', ')', '등', '사회', '관계', '망', '서비스', '(', 'SNS', ')', '에는', '전날', '부터', '다양하다', '투표', '인증', '사진', '이', '올라오다', '.', '이', '중', '젊다', '세대', '의', '눈길', '을', '사로자다', '것', '은', '손바닥', '만', '하다', '크기', '의', '종이', '를', '들다', '찍다', '인증', '사진', '이다', '.', '이다', '유권자', '가', '투표소', '로', '향', '하다', '전', '직접', '챙기다', '간', '인증', '용지', '다', '.', '손등', '에', '도장', '을', '남다', '방식', '에서', '벗어나다', '투표', '인증', '을', '위', '한', '이미지', '를', '만들다', '것', '이다', '.', '인증', '용지', '에', '등장', '하다', '이미지', '는', '만화', '캐릭터', ',', '이모티콘', '캐릭터', ',', '프로야구', '팀', '등', '다양하다', '.', '자신', '의', '관심', '분야', '에', '맞추다', '직접', '용지', '를', '만들다', 'SNS', '에', '무료', '배포', '되다', '이미지', '를', '출력', '하다', '사용', '한', '다', '.', '아이돌', '팬', '들', '은', '최애', '멤버', '의', '포토', '카드', '를', '활용', '하다', '하다', '.', '인증', '방법', '은', '정해지다', '있다', '.', '그림', '속', '비우다', '공간', '이나', '글자', '에', '기표', '도장', '을', '찍다', '이미지', '를', '완성', '시키다', '되다', '.']

# %%
print(okt.morphs('비워주세요, 챙겨, 생겨, 가르쳐주는', stem=True))
# Out:
# ['비우다', ',', '챙기다', ',', '생기다', ',', '가르치다']

# %% [markdown]
# #### Mecab

# %%
print(mecab.pos(u'질문이나 건의 문의 사항은 깃헙 이슈 트래커에 남겨주세요.'))
print(mecab.morphs(u'우리나라에는 무릎 치료를 잘하는 정형외과가 없는가!'))
print(mecab.pos(u'우는 사람은 울면 안 됀다고 생각하면서 운다 굳혔다고'))
# Out:
# [('질문', 'NNG'), ('이나', 'JC'), ('건', 'NNG'), ('의', 'JKG'), ('문', 'NNG'), ('의', 'JKG'), ('사항', 'NNG'), ('은', 'JX'), ('깃', 'NNG'), ('헙', 'UNKNOWN'), ('이슈', 'NNG'), ('트래커', 'NNP'), ('에', 'JKB'), ('남겨', 'VV+EC'), ('주', 'VX'), ('세요', 'EP+EF'), ('.', 'SF')]
# ['우리', '나라', '에', '는', '무릎', '치료', '를', '잘', '하', '는', '정형', '외과', '가', '없', '는가', '!']
# [('우', 'VV'), ('는', 'ETM'), ('사람', 'NNG'), ('은', 'JX'), ('울면', 'NNG'), ('안', 'MAG'), ('됀', 'NNG'), ('다고', 'VCP+EC'), ('생각', 'NNG'), ('하', 'XSV'), ('면서', 'EC'), ('운다', 'VV+EC'), ('굳혔', 'VV+EP'), ('다고', 'EC')]

# %%
print(mecab.pos(u'질문이나 건의 사항은 깃헙 이슈 트래커에 남겨주세요. 굳혔다고'))
print()
print(mecab.pos(u'질문이나 건의 사항은 깃헙 이슈 트래커에 남겨주세요. 굳혔다고'))
print()
print(mecab.morphs(u'남기고, 남기는데, 남기니, 남기면, 남긴, 남기는, 남길, 남깁니다'))
# Out:
# [('질문', 'NNG'), ('이나', 'JC'), ('건', 'NNG'), ('의', 'JKG'), ('사항', 'NNG'), ('은', 'JX'), ('깃', 'NNG'), ('헙', 'UNKNOWN'), ('이슈', 'NNG'), ('트래커', 'NNP'), ('에', 'JKB'), ('남겨', 'VV+EC'), ('주', 'VX'), ('세요', 'EP+EF'), ('.', 'SF'), ('굳혔', 'VV+EP'), ('다고', 'EC')]
#
# [('질문', 'NNG'), ('이나', 'JC'), ('건', 'NNG'), ('의', 'JKG'), ('사항', 'NNG'), ('은', 'JX'), ('깃', 'NNG'), ('헙', 'UNKNOWN'), ('이슈', 'NNG'), ('트래커', 'NNP'), ('에', 'JKB'), ('남겨', 'VV+EC'), ('주', 'VX'), ('세요', 'EP+EF'), ('.', 'SF'), ('굳혔', 'VV+EP'), ('다고', 'EC')]
#
# ['남기', '고', ',', '남기', '는데', ',', '남기', '니', ',', '남기', '면', ',', '남긴', ',', '남기', '는', ',', '남길', ',', '남', '깁니다']

# %%
print(mecab.morphs(u'사람의 문의 다리'))
# Out:
# ['사람', '의', '문', '의', '다리']

# %% [markdown]
# #### Kkma

# %%
print(kkma.pos(u'질문이나 건의 사항은 깃헙 이슈 트래커에 남겨주세요.'))
print(kkma.morphs(u'우리나라에는 무릎 치료를 잘하는 정형외과가 없는가!'))
print(kkma.pos(u'우는 사람은 울면 안 됀다고 생각하면서 운다 굳혔다고'))
# Out:
# [('질문', 'NNG'), ('이나', 'JC'), ('건의', 'NNG'), ('사항', 'NNG'), ('은', 'JX'), ('깃헙', 'UN'), ('이슈', 'NNG'), ('트래커', 'UN'), ('에', 'JKM'), ('남기', 'VV'), ('어', 'ECS'), ('주', 'VXV'), ('세요', 'EFN'), ('.', 'SF')]
# ['우리나라', '에', '는', '무릎', '치료', '를', '잘하', '는', '정형외과', '가', '없', '는가', '!']
# [('울', 'VV'), ('는', 'ETD'), ('사람', 'NNG'), ('은', 'JX'), ('울', 'VV'), ('면', 'ECE'), ('안', 'MAG'), ('돼', 'VV'), ('ㄴ다고', 'ECE'), ('생각', 'NNG'), ('하', 'XSV'), ('면서', 'ECE'), ('울', 'VV'), ('ㄴ다', 'ECS'), ('굳히', 'VV'), ('었', 'EPT'), ('다고', 'EFN')]

# %%
print(kkma.pos(u'질문이나 건의 사항은 깃헙 이슈 트래커에 남겨주세요. 굳혔다고'))
print()
print(kkma.pos(u'질문이나 건의 사항은 깃헙 이슈 트래커에 남겨주세요. 굳혔다고'))
print()
print(kkma.morphs(u'남기고, 남기는데, 남기니, 남기면, 남긴, 남기는, 남길, 남깁니다'))
# Out:
# [('질문', 'NNG'), ('이나', 'JC'), ('건의', 'NNG'), ('사항', 'NNG'), ('은', 'JX'), ('깃헙', 'UN'), ('이슈', 'NNG'), ('트래커', 'UN'), ('에', 'JKM'), ('남기', 'VV'), ('어', 'ECS'), ('주', 'VXV'), ('세요', 'EFN'), ('.', 'SF'), ('굳히', 'VV'), ('었', 'EPT'), ('다고', 'EFN')]
#
# [('질문', 'NNG'), ('이나', 'JC'), ('건의', 'NNG'), ('사항', 'NNG'), ('은', 'JX'), ('깃헙', 'UN'), ('이슈', 'NNG'), ('트래커', 'UN'), ('에', 'JKM'), ('남기', 'VV'), ('어', 'ECS'), ('주', 'VXV'), ('세요', 'EFN'), ('.', 'SF'), ('굳히', 'VV'), ('었', 'EPT'), ('다고', 'EFN')]
#
# ['남기', '고', ',', '남기', '는데', ',', '남기', '니', ',', '남기', '면', ',', '남기', 'ㄴ', ',', '남기', '는', ',', '남기', 'ㄹ', ',', '남기', 'ㅂ니다']

# %%
print(kkma.morphs(example))
# Out:
# ['6', '일', '이', 'ㄴ', '스타', '그램', '과', '엑스', '(', 'X', '·', '옛', '트위터', ')', '등', '사회', '관계', '망', '서비스', '(', 'SNS', ')', '에', '는', '전날', '부터', '다양', '하', 'ㄴ', '투표', '인증', '사진', '이', '올라오', '았', '다', '.', '이', '중', '젊', '은', '세대', '의', '눈길', '을', '사로잡', '은', '것', '은', '손바닥', '만', '한', '크기', '의', '종이', '를', '들', '고', '찍', '은', '인증', '사진', '이', '다', '.', '일', '는', '유권자', '가', '투표소', '로', '향하', '기', '전', '직접', '챙기', '어', '간', '인증', '용지', '이', '다', '.', '손등', '에', '도장', '을', '남기', '더', 'ㄴ', '방식', '에서', '벗', '어', '나', '투표', '인증', '을', '위하', 'ㄴ', '이미지', '를', '만들', 'ㄴ', '것', '이', '다', '.', '인증', '용지', '에', '등장', '하', '는', '이미지', '는', '만화', '캐릭터', ',', '이모', '티', '콘', '캐릭터', ',', '프로', '야구팀', '등', '다양', '하', '다', '.', '자신', '의', '관심', '분야', '에', '맞추', '어', '직접', '용지', '를', '만들', '거나', 'SNS', '에', '무료', '배포', '되', 'ㄴ', '이미지', '를', '출력', '하', '어', '사용하', 'ㄴ다', '.', '아이돌', '팬', '들', '은', '최', '애', '멤버', '의', '포토', '카드', '를', '활용', '하', '기', '도', '하', 'ㄴ다', '.', '인증', '방법', '은', '정해지', '어', '있',
# ...

# %%
print(kkma.morphs('비워, 챙겨, 생겨, 문의 밑'))
# Out:
# ['비우', '어', ',', '챙기', '어', ',', '생기', '어', ',', '문의', '밑']

# %%
print(kkma.morphs(u'사람의 문의 사항 문과 책. 문과 책은 물건이다. 사람과의 평화적 공존 '))
# Out:
# ['사람', '의', '문의', '사항', '문과', '책', '.', '문과', '책', '은', '물건', '이', '다', '.', '사람', '과', '의', '평화적', '공존']

# %%
print(kkma.pos('사로잡다'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 print(kkma.pos('사로잡다', stem=True))
#
# TypeError: Kkma.pos() got an unexpected keyword argument 'stem'

# %% [markdown]
# #### Komoran

# %%
print(komoran.pos(u'질문이나 건의사항은 깃헙 이슈 트래커에 남겨주세요.'))
print(komoran.morphs(u'우리나라에는 무릎 치료를 잘하는 정형외과가 없는가!'))
print(komoran.pos(u'우는 사람은 울면 안 됀다고 생각하면서 운다 굳혔다고'))
# Out:
# [('질문', 'NNG'), ('이나', 'JC'), ('건의', 'NNP'), ('사항', 'NNG'), ('은', 'JX'), ('깃헙', 'NA'), ('이슈', 'NNG'), ('트', 'VV'), ('래', 'EC'), ('크', 'VA'), ('어', 'EC'), ('에', 'JKB'), ('남기', 'VV'), ('어', 'EC'), ('주', 'VX'), ('시', 'EP'), ('어요', 'EF'), ('.', 'SF')]
# ['우리나라', '에', '는', '무릎', '치료', '를', '잘', '하', '는', '정형외과', '가', '없', '는가', '!']
# [('울', 'VV'), ('는', 'ETM'), ('사람', 'NNG'), ('은', 'JX'), ('울면', 'NNP'), ('안', 'MAG'), ('되', 'VV'), ('어', 'EC'), ('ㄴ다고', 'EC'), ('생각', 'NNG'), ('하', 'XSV'), ('면서', 'EC'), ('울', 'VV'), ('ㄴ다', 'EC'), ('굳히', 'VV'), ('었', 'EP'), ('다고', 'EC')]

# %%
print(komoran.pos(u'질문이나 건의 사항은 깃헙 이슈 트래커에 남겨주세요. 굳혔다고'))
print()
print(komoran.pos(u'질문이나 건의 사항은 깃헙 이슈 트래커에 남겨주세요. 굳혔다고'))
print()
print(komoran.morphs(u'남기고, 남기는데, 남기니, 남기면, 남긴, 남기는, 남길, 남깁니다'))
# Out:
# [('질문', 'NNG'), ('이나', 'JC'), ('건의', 'NNP'), ('사항', 'NNG'), ('은', 'JX'), ('깃헙', 'NA'), ('이슈', 'NNG'), ('트', 'VV'), ('래', 'EC'), ('크', 'VA'), ('어', 'EC'), ('에', 'JKB'), ('남기', 'VV'), ('어', 'EC'), ('주', 'VX'), ('시', 'EP'), ('어요', 'EF'), ('.', 'SF'), ('굳히', 'VV'), ('었', 'EP'), ('다고', 'EC')]
#
# [('질문', 'NNG'), ('이나', 'JC'), ('건의', 'NNP'), ('사항', 'NNG'), ('은', 'JX'), ('깃헙', 'NA'), ('이슈', 'NNG'), ('트', 'VV'), ('래', 'EC'), ('크', 'VA'), ('어', 'EC'), ('에', 'JKB'), ('남기', 'VV'), ('어', 'EC'), ('주', 'VX'), ('시', 'EP'), ('어요', 'EF'), ('.', 'SF'), ('굳히', 'VV'), ('었', 'EP'), ('다고', 'EC')]
#
# ['남기', '고', ',', '남기', '는데', ',', '남기', '니', ',', '남기', '면', ',', '남기', 'ㄴ', ',', '남기', '는', ',', '남기', 'ㄹ', ',', '남기', 'ㅂ니다']

# %%
print(komoran.nouns(u'사람의 문의 다리 문과 과목은 최악이다. 문과. 사람과의 평화적 공존'))
# Out:
# ['사람', '문', '다리', '문', '과목', '최악', '문과', '사람과', '평화', '공존']
